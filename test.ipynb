# %%
! python main_opt.py --seed=0 --save_dir="./data/supervised_0" --substrate='lenia_flow' --time_sampling=16 --prompts="a caterpillar" --coef_prompt=1. --coef_softmax=0. --coef_oe=0. --bs=1 --rollout_steps=150 --pop_size=8 --n_iters=100 --sigma=0.2
# Out:
# Traceback (most recent call last):
#   File "/home/coder/project/main_opt.py", line 8, in <module>
#     import jax
# ModuleNotFoundError: No module named 'jax'

# %%
import sys, os
bad = "/home/coder/.local/lib/python38-conda-cuda"
sys.path = [p for p in sys.path if not p.startswith(bad)]
os.environ["PYTHONNOUSERSITE"] = "1"

# %%
1
# Out:
# 1

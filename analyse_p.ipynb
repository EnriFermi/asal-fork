# %%
from scripts.snapshot_loader import list_snapshot_files, load_snapshots

EXP_FOLDER = "data/interp_supervised_0_1/interp_6/snapshots_P"

# %%
list_snapshot_files(EXP_FOLDER)
# Out:
# [{'path': 'data/interp_supervised_0_1/interp_6/snapshots_P/P_steps_0_900__secs_0.000_3.600__idx_0000.npz',
#   'start_step': 0,
#   'end_step': 900,
#   'start_sec': 0.0,
#   'end_sec': 3.6,
#   'idx': 0}]

# %%
steps, P = load_snapshots(
        EXP_FOLDER,
        start_step=150,
        end_step=500
    )

# %%
steps
# Out:
# array([200, 300, 400, 500])

# %%
import numpy as np
np.unique(P[2]).shape
# Out:
# (315,)
